# %%
import os
import pandas as pd

# %%
#Read the data set and see what features and records it has.
df=pd.read_csv('college_graduation_rate_at_fouryear_institutions_within_six_years_of_start_usafacts.csv', header=[0], index_col=[0])
print(df.head())
# Out:
#                                                                  2002 2003  \
# Years
# College graduation rate at four-year institutio...   0.55381288864864  NaN
#     By gender                                                     NaN  NaN
#         Men (%)                                     0.520100996291676  NaN
#         Women (%)                                   0.581973063444367  NaN
#     By type of institution                                        NaN  NaN
#
#                                                    2004 2005  \
# Years
# College graduation rate at four-year institutio...  NaN  NaN
#     By gender                                       NaN  NaN
#         Men (%)                                     NaN  NaN
#         Women (%)                                   NaN  NaN
#     By type of institution                          NaN  NaN
#
#                                                                  2006 2007  \
# Years
# College graduation rate at four-year institutio...   0.57553142511211  NaN
#     By gender                                                     NaN  NaN
#         Men (%)                                     0.543327549802971  NaN
#         Women (%)                                   0.601939110749673  NaN
#     By type of institution                                        NaN  NaN
#
#                                                                  2008  \
# Years
# College graduation rate at four-year institutio...  0.573966214532093
#     By gender                                                     NaN
#         Men (%)                                     0.543560497506735
#         Women (%)                                   0.598732758897386
#     By type of institution                                        NaN
#
#                                                         2009      2010  \
# Years
# College graduation rate at four-year institutio...  0.578050  0.584098
#     By gender                                            NaN       NaN
#         Men (%)                                     0.550899  0.556412
#         Women (%)                                   0.600191  0.606913
#     By type of institution                               NaN       NaN
#
#                                                         2011      2012  \
# Years
# College graduation rate at four-year institutio...  0.586214  0.591774
#     By gender                                            NaN       NaN
#         Men (%)                                     0.560130  0.564944
#         Women (%)                                   0.607764  0.614081
#     By type of institution                               NaN       NaN
#
#                                                         2013      2014  \
# Years
# College graduation rate at four-year institutio...  0.594263  0.596454
#     By gender                                            NaN       NaN
#         Men (%)                                     0.564859  0.565169
#         Women (%)                                   0.618837  0.622601
#     By type of institution                               NaN       NaN
#
#                                                         2015      2016  \
# Years
# College graduation rate at four-year institutio...  0.594214  0.596680
#     By gender                                            NaN       NaN
#         Men (%)                                     0.562170  0.565198
#         Women (%)                                   0.621170  0.623342
#     By type of institution                               NaN       NaN
#
#                                                         2017      2018  \
# Years
# College graduation rate at four-year institutio...  0.603982  0.623822
#     By gender                                            NaN       NaN
#         Men (%)                                     0.572731  0.589524
#         Women (%)                                   0.630251  0.652844
#     By type of institution                               NaN       NaN
#
#                                                         2019      2020  \
# Years
# College graduation rate at four-year institutio...  0.633912  0.640323
#     By gender                                            NaN       NaN
#         Men (%)                                     0.599392  0.604957
#         Women (%)                                   0.662823  0.669998
#     By type of institution                               NaN       NaN
#
#                                                         2021
# Years
# College graduation rate at four-year institutio...  0.645487
#     By gender                                            NaN
#         Men (%)                                     0.611384
#         Women (%)                                   0.673904
#     By type of institution                               NaN

# %%
df.shape
# Out:
# (20, 20)

# %%
#Checking the data type of each column.
df.info()
#Why do the years between 2002 and 2008 all come up as object when the rest are floats?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, College graduation rate at four-year institutions within six years of start (%) to Exported on: 05/04/2024
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2002    14 non-null     object
#  1   2003    2 non-null      object
#  2   2004    1 non-null      object
#  3   2005    2 non-null      object
#  4   2006    13 non-null     object
#  5   2007    2 non-null      object
#  6   2008    14 non-null     object
#  7   2009    12 non-null     float64
#  8   2010    12 non-null     float64
#  9   2011    13 non-null     float64
#  10  2012    13 non-null     float64
#  11  2013    13 non-null     float64
#  12  2014    13 non-null     float64
#  13  2015    13 non-null     float64
#  14  2016    13 non-null     float64
#  15  2017    13 non-null     float64
#  16  2018    13 non-null     float64
#  17  2019    13 non-null     float64
#  18  2020    13 non-null     float64
#  19  2021    13 non-null     float64
# dtypes: float64(13), object(7)
# memory usage: 3.3+ KB

# %%
#Switch the rows and columns so that the years become the records and the different rates become the columns.
df_T = df.transpose()
print(df_T.head())
# Out:
# Years College graduation rate at four-year institutions within six years of start (%)  \
# 2002                                    0.55381288864864
# 2003                                                 NaN
# 2004                                                 NaN
# 2005                                                 NaN
# 2006                                    0.57553142511211
#
# Years     By gender            Men (%)          Women (%)  \
# 2002            NaN  0.520100996291676  0.581973063444367
# 2003            NaN                NaN                NaN
# 2004            NaN                NaN                NaN
# 2005            NaN                NaN                NaN
# 2006            NaN  0.543327549802971  0.601939110749673
#
# Years     By type of institution         Public (%)         Nonprofit (%)  \
# 2002                         NaN  0.516757777154202     0.631472458619114
# 2003                         NaN                NaN                   NaN
# 2004                         NaN                NaN                   NaN
# 2005                         NaN                NaN                   NaN
# 2006                         NaN  0.548095548918383     0.644546018990121
#
# Years         For-profit (%)     By race and ethnicity or residency  \
# 2002       0.279918032786885                                    NaN
# 2003                     NaN                                    NaN
# 2004                     NaN                                    NaN
# 2005                     NaN                                    NaN
# 2006       0.312565360791569                                    NaN
#
# Years         White, non-Hispanic (%)          Black (%)         Hispanic (%)  \
# 2002                0.581166854588679  0.389257038042745    0.456703910614525
# 2003                              NaN                NaN                  NaN
# 2004                              NaN                NaN                  NaN
# 2005                              NaN                NaN                  NaN
# 2006                0.602346402839636  0.420672900548658    0.490635121813829
#
# Years         Asian or Pacific Islander (%)         Native American (%)  \
# 2002                      0.633656936372871           0.380134228187919
# 2003                                    NaN                         NaN
# 2004                                    NaN                         NaN
# 2005                                    NaN                         NaN
# 2006                      0.667298224262875           0.402151326243736
#
# Years         Two or more races (%)         Non-resident foreign (%) Sources:  \
# 2002                            NaN                0.580415370723387      NaN
# 2003                            NaN                              NaN      NaN
# 2004                            NaN                              NaN      NaN
# 2005                            NaN                              NaN      NaN
# 2006                            NaN                0.595616781465247      NaN
#
# Years          NaN                                                NaN  \
# 2002        Agency           National Center for Education Statistics
# 2003        Source       Digest of Education Statistics, Table 326.10
# 2004         Table                                                NaN
# 2005           Url  https://nces.ed.gov/programs/digest/d19/tables...
# 2006   Direct Link                                                NaN
#
# Years Exported on: 05/04/2024
# 2002                      NaN
# 2003                      NaN
# 2004                      NaN
# 2005                      NaN
# 2006                      NaN

# %%
df_T.columns
# Out:
# Index(['College graduation rate at four-year institutions within six years of start (%)',
#                                                                          '    By gender',
#                                                                        '        Men (%)',
#                                                                      '        Women (%)',
#                                                             '    By type of institution',
#                                                                     '        Public (%)',
#                                                                  '        Nonprofit (%)',
#                                                                 '        For-profit (%)',
#                                                 '    By race and ethnicity or residency',
#                                                        '        White, non-Hispanic (%)',
#                                                                      '        Black (%)',
#                                                                   '        Hispanic (%)',
#                                                  '        Asian or Pacific Islander (%)',
#                                                            '        Native American (%)',
#                                                          '        Two or more races (%)',
#                                                       '        Non-resident foreign (%)',
#                                                                               'Sources:',
#                                                                                      nan,
#                                                                                      nan,
#                                                                'Exported on: 05/04/2024'],
#       dtype='object', name='Years')

# %%
#Drop the columns with all NaN values.
df=df_T.drop([ '    By gender','    By type of institution','    By race and ethnicity or residency', 'Sources:', 'Exported on: 05/04/2024'], axis=1)

# %%
df.columns
# Out:
# Index(['College graduation rate at four-year institutions within six years of start (%)',
#                                                                        '        Men (%)',
#                                                                      '        Women (%)',
#                                                                     '        Public (%)',
#                                                                  '        Nonprofit (%)',
#                                                                 '        For-profit (%)',
#                                                        '        White, non-Hispanic (%)',
#                                                                      '        Black (%)',
#                                                                   '        Hispanic (%)',
#                                                  '        Asian or Pacific Islander (%)',
#                                                            '        Native American (%)',
#                                                          '        Two or more races (%)',
#                                                       '        Non-resident foreign (%)',
#                                                                                      nan,
#                                                                                      nan],
#       dtype='object', name='Years')

# %%
df.head()
#Still need to eliminate the nan columns, but cannot use the drop method because of the name at this moment.
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['College graduation rate at four-year institutions within six years of start (%)',
#        '        Men (%)', '        Women (%)', '        Public (%)',
#        '        Nonprofit (%)', '        For-profit (%)',
#        '        White, non-Hispanic (%)', '        Black (%)',
#        '        Hispanic (%)', '        Asian or Pacific Islander (%)',
#        '        Native American (%)', '        Two or more races (%)',
#        '        Non-resident foreign (%)'],
#       dtype='object', name='Years')

# %%
print(df)
# Out:
# Years College graduation rate at four-year institutions within six years of start (%)  \
# 2002                                    0.55381288864864
# 2003                                                 NaN
# 2004                                                 NaN
# 2005                                                 NaN
# 2006                                    0.57553142511211
# 2007                                                 NaN
# 2008                                   0.573966214532093
# 2009                                             0.57805
# 2010                                            0.584098
# 2011                                            0.586214
# 2012                                            0.591774
# 2013                                            0.594263
# 2014                                            0.596454
# 2015                                            0.594214
# 2016                                             0.59668
# 2017                                            0.603982
# 2018                                            0.623822
# 2019                                            0.633912
# 2020                                            0.640323
# 2021                                            0.645487
#
# Years            Men (%)          Women (%)         Public (%)  \
# 2002   0.520100996291676  0.581973063444367  0.516757777154202
# 2003                 NaN                NaN                NaN
# 2004                 NaN                NaN                NaN
# 2005                 NaN                NaN                NaN
# 2006   0.543327549802971  0.601939110749673  0.548095548918383
# 2007                 NaN                NaN                NaN
# 2008   0.543560497506735  0.598732758897386  0.550434310870555
# 2009            0.550899           0.600191           0.557902
# 2010            0.556412           0.606913           0.561067
# 2011             0.56013           0.607764           0.565795
# 2012            0.564944           0.614081            0.57242
# 2013            0.564859           0.618837           0.576658
# 2014            0.565169           0.622601             0.5846
# 2015             0.56217            0.62117           0.585633
# 2016            0.565198           0.623342           0.589078
# 2017            0.572731           0.630251           0.596866
# 2018            0.589524           0.652844           0.611748
# 2019            0.599392           0.662823           0.623631
# 2020            0.604957           0.669998           0.631193
# 2021            0.611384           0.673904           0.636137
#
# Years         Nonprofit (%)         For-profit (%)  \
# 2002      0.631472458619114      0.279918032786885
# 2003                    NaN                    NaN
# 2004                    NaN                    NaN
# 2005                    NaN                    NaN
# 2006      0.644546018990121      0.312565360791569
# 2007                    NaN                    NaN
# 2008      0.648155170684328      0.228399903463256
# 2009               0.651467               0.235418
# 2010               0.654606               0.285577
# 2011               0.651707               0.291478
# 2012               0.655299                0.31542
# 2013               0.653292               0.318857
# 2014               0.653894               0.264448
# 2015               0.656114               0.227114
# 2016               0.658576               0.241266
# 2017               0.664735               0.208261
# 2018               0.671983               0.253878
# 2019               0.679435               0.263391
# 2020               0.680463               0.290184
# 2021               0.685202               0.297902
#
# Years         White, non-Hispanic (%)          Black (%)         Hispanic (%)  \
# 2002                0.581166854588679  0.389257038042745    0.456703910614525
# 2003                              NaN                NaN                  NaN
# 2004                              NaN                NaN                  NaN
# 2005                              NaN                NaN                  NaN
# 2006                0.602346402839636  0.420672900548658    0.490635121813829
# 2007                              NaN                NaN                  NaN
# 2008                0.603768523486208  0.401545164896165    0.490234326466715
# 2009                          0.61087           0.395233             0.491072
# 2010                         0.616267           0.396392             0.501528
# 2011                         0.619853           0.394541              0.51006
# 2012                         0.625243           0.402081             0.518636
# 2013                         0.628709           0.407409             0.525122
# 2014                         0.632328           0.408864             0.535109
# 2015                         0.632711           0.394851             0.536405
# 2016                          0.63743           0.393298             0.543477
# 2017                         0.643504           0.398139             0.550059
# 2018                         0.659079           0.423626             0.567481
# 2019                         0.666553           0.442683             0.578622
# 2020                         0.673975           0.449992             0.586907
# 2021                         0.678898           0.457135              0.59148
#
# Years         Asian or Pacific Islander (%)         Native American (%)  \
# 2002                      0.633656936372871           0.380134228187919
# 2003                                    NaN                         NaN
# 2004                                    NaN                         NaN
# 2005                                    NaN                         NaN
# 2006                      0.667298224262875           0.402151326243736
# 2007                                    NaN                         NaN
# 2008                      0.672400413864459           0.384138381201044
# 2009                               0.680914                    0.386754
# 2010                               0.687128                    0.394369
# 2011                               0.692241                    0.392702
# 2012                                0.70115                    0.402058
# 2013                                 0.7004                    0.406114
# 2014                               0.706499                    0.410138
# 2015                               0.722884                    0.411794
# 2016                               0.728473                    0.384795
# 2017                               0.733706                    0.376695
# 2018                               0.747475                    0.406349
# 2019                               0.754715                    0.407883
# 2020                               0.763317                    0.414597
# 2021                               0.771229                    0.433552
#
# Years         Two or more races (%)         Non-resident foreign (%)
# 2002                            NaN                0.580415370723387
# 2003                            NaN                              NaN
# 2004                            NaN                              NaN
# 2005                            NaN                              NaN
# 2006                            NaN                0.595616781465247
# 2007                            NaN                              NaN
# 2008                            NaN                0.553781351713575
# 2009                            NaN                         0.561488
# 2010                            NaN                          0.61586
# 2011                       0.642474                         0.626358
# 2012                       0.665813                         0.635725
# 2013                       0.678454                         0.638577
# 2014                       0.652265                         0.656868
# 2015                       0.592231                         0.688227
# 2016                       0.594382                         0.700283
# 2017                         0.5712                         0.709762
# 2018                       0.577385                         0.714947
# 2019                       0.593046                         0.722646
# 2020                       0.594801                         0.720727
# 2021                       0.600873                         0.725454

# %%
#It seems the years from 2002 to 2010 are the most inconsistent. These years contain the most NaN values. 
#There are too many NaN values to interpolate and the mean does not make a reasonable replacement for values increasing with time.
df = df.dropna()
print(df)
# Out:
# Years College graduation rate at four-year institutions within six years of start (%)  \
# 2011                                            0.586214
# 2012                                            0.591774
# 2013                                            0.594263
# 2014                                            0.596454
# 2015                                            0.594214
# 2016                                             0.59668
# 2017                                            0.603982
# 2018                                            0.623822
# 2019                                            0.633912
# 2020                                            0.640323
# 2021                                            0.645487
#
# Years         Men (%)         Women (%)         Public (%)  \
# 2011          0.56013          0.607764           0.565795
# 2012         0.564944          0.614081            0.57242
# 2013         0.564859          0.618837           0.576658
# 2014         0.565169          0.622601             0.5846
# 2015          0.56217           0.62117           0.585633
# 2016         0.565198          0.623342           0.589078
# 2017         0.572731          0.630251           0.596866
# 2018         0.589524          0.652844           0.611748
# 2019         0.599392          0.662823           0.623631
# 2020         0.604957          0.669998           0.631193
# 2021         0.611384          0.673904           0.636137
#
# Years         Nonprofit (%)         For-profit (%)  \
# 2011               0.651707               0.291478
# 2012               0.655299                0.31542
# 2013               0.653292               0.318857
# 2014               0.653894               0.264448
# 2015               0.656114               0.227114
# 2016               0.658576               0.241266
# 2017               0.664735               0.208261
# 2018               0.671983               0.253878
# 2019               0.679435               0.263391
# 2020               0.680463               0.290184
# 2021               0.685202               0.297902
#
# Years         White, non-Hispanic (%)         Black (%)         Hispanic (%)  \
# 2011                         0.619853          0.394541              0.51006
# 2012                         0.625243          0.402081             0.518636
# 2013                         0.628709          0.407409             0.525122
# 2014                         0.632328          0.408864             0.535109
# 2015                         0.632711          0.394851             0.536405
# 2016                          0.63743          0.393298             0.543477
# 2017                         0.643504          0.398139             0.550059
# 2018                         0.659079          0.423626             0.567481
# 2019                         0.666553          0.442683             0.578622
# 2020                         0.673975          0.449992             0.586907
# 2021                         0.678898          0.457135              0.59148
#
# Years         Asian or Pacific Islander (%)         Native American (%)  \
# 2011                               0.692241                    0.392702
# 2012                                0.70115                    0.402058
# 2013                                 0.7004                    0.406114
# 2014                               0.706499                    0.410138
# 2015                               0.722884                    0.411794
# 2016                               0.728473                    0.384795
# 2017                               0.733706                    0.376695
# 2018                               0.747475                    0.406349
# 2019                               0.754715                    0.407883
# 2020                               0.763317                    0.414597
# 2021                               0.771229                    0.433552
#
# Years         Two or more races (%)         Non-resident foreign (%)
# 2011                       0.642474                         0.626358
# 2012                       0.665813                         0.635725
# 2013                       0.678454                         0.638577
# 2014                       0.652265                         0.656868
# 2015                       0.592231                         0.688227
# 2016                       0.594382                         0.700283
# 2017                         0.5712                         0.709762
# 2018                       0.577385                         0.714947
# 2019                       0.593046                         0.722646
# 2020                       0.594801                         0.720727
# 2021                       0.600873                         0.725454

# %%
print(df.dtypes)
# Out:
# Years
# College graduation rate at four-year institutions within six years of start (%)    object
#         Men (%)                                                                    object
#         Women (%)                                                                  object
#         Public (%)                                                                 object
#         Nonprofit (%)                                                              object
#         For-profit (%)                                                             object
#         White, non-Hispanic (%)                                                    object
#         Black (%)                                                                  object
#         Hispanic (%)                                                               object
#         Asian or Pacific Islander (%)                                              object
#         Native American (%)                                                        object
#         Two or more races (%)                                                      object
#         Non-resident foreign (%)                                                   object
# dtype: object

# %%
dfcols = df.columns
print(dfcols)
# Out:
# Index(['College graduation rate at four-year institutions within six years of start (%)',
#        '        Men (%)', '        Women (%)', '        Public (%)',
#        '        Nonprofit (%)', '        For-profit (%)',
#        '        White, non-Hispanic (%)', '        Black (%)',
#        '        Hispanic (%)', '        Asian or Pacific Islander (%)',
#        '        Native American (%)', '        Two or more races (%)',
#        '        Non-resident foreign (%)'],
#       dtype='object', name='Years')

# %%
#The columns should be numeric values. The rows before transposing were numeric.
df[dfcols] = df[dfcols].apply(pd.to_numeric, errors='coerce')
print(df.dtypes)
# Out:
# Years
# College graduation rate at four-year institutions within six years of start (%)    float64
#         Men (%)                                                                    float64
#         Women (%)                                                                  float64
#         Public (%)                                                                 float64
#         Nonprofit (%)                                                              float64
#         For-profit (%)                                                             float64
#         White, non-Hispanic (%)                                                    float64
#         Black (%)                                                                  float64
#         Hispanic (%)                                                               float64
#         Asian or Pacific Islander (%)                                              float64
#         Native American (%)                                                        float64
#         Two or more races (%)                                                      float64
#         Non-resident foreign (%)                                                   float64
# dtype: object

# %%
#Now that the columns are numeric, they need to be described.
df.describe([.25, .5, .75])
# Out:
# Years  College graduation rate at four-year institutions within six years of start (%)  \
# count                                          11.000000
# mean                                            0.609739
# std                                             0.021755
# min                                             0.586214
# 25%                                             0.594239
# 50%                                             0.596680
# 75%                                             0.628867
# max                                             0.645487
#
# Years          Men (%)          Women (%)          Public (%)  \
# count        11.000000          11.000000           11.000000
# mean          0.578224           0.636147            0.597614
# std           0.019236           0.024001            0.024415
# min           0.560130           0.607764            0.565795
# 25%           0.564901           0.620004            0.580629
# 50%           0.565198           0.623342            0.589078
# 75%           0.594458           0.657833            0.617690
# max           0.611384           0.673904            0.636137
#
# Years          Nonprofit (%)          For-profit (%)  \
# count              11.000000               11.000000
# mean                0.664609                0.270200
# std                 0.012467                0.035927
# min                 0.651707                0.208261
# 25%                 0.654596                0.247572
# 50%                 0.658576                0.264448
# 75%                 0.675709                0.294690
# max                 0.685202                0.318857
#
# Years          White, non-Hispanic (%)          Black (%)  \
# count                        11.000000          11.000000
# mean                          0.645298           0.415693
# std                           0.020760           0.023827
# min                           0.619853           0.393298
# 25%                           0.630519           0.396495
# 50%                           0.637430           0.407409
# 75%                           0.662816           0.433154
# max                           0.678898           0.457135
#
# Years          Hispanic (%)          Asian or Pacific Islander (%)  \
# count             11.000000                              11.000000
# mean               0.549396                               0.729281
# std                0.028019                               0.027338
# min                0.510060                               0.692241
# 25%                0.530116                               0.703825
# 50%                0.543477                               0.728473
# 75%                0.573052                               0.751095
# max                0.591480                               0.771229
#
# Years          Native American (%)          Two or more races (%)  \
# count                    11.000000                      11.000000
# mean                      0.404244                       0.614811
# std                       0.015344                       0.037574
# min                       0.376695                       0.571200
# 25%                       0.397380                       0.592638
# 50%                       0.406349                       0.594801
# 75%                       0.410966                       0.647369
# max                       0.433552                       0.678454
#
# Years          Non-resident foreign (%)
# count                         11.000000
# mean                           0.685416
# std                            0.038595
# min                            0.626358
# 25%                            0.647723
# 50%                            0.700283
# 75%                            0.717837
# max                            0.725454

# %%
#The ranges of each column.
col_ranges = df.max() - df.min()
print(col_ranges)
# Out:
# Years
# College graduation rate at four-year institutions within six years of start (%)    0.059273
#         Men (%)                                                                    0.051254
#         Women (%)                                                                  0.066139
#         Public (%)                                                                 0.070342
#         Nonprofit (%)                                                              0.033495
#         For-profit (%)                                                             0.110596
#         White, non-Hispanic (%)                                                    0.059045
#         Black (%)                                                                  0.063838
#         Hispanic (%)                                                               0.081420
#         Asian or Pacific Islander (%)                                              0.078988
#         Native American (%)                                                        0.056857
#         Two or more races (%)                                                      0.107254
#         Non-resident foreign (%)                                                   0.099095
# dtype: float64
